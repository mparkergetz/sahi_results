# %%
import pandas as pd

# %%
sahi_detections = pd.read_csv('csv/detections.csv')

sahi_detections.sort_values('filename')
# Out:
#                      filename  \
# 1095318  pi10_20240718_105606
# 1000978  pi10_20240718_105607
# 1025844  pi10_20240718_105609
# 1106638  pi10_20240718_105610
# 1258626  pi10_20240718_105614
# ...                       ...
# 2577720   pi9_20240804_174616
# 2406673   pi9_20240804_174617
# 2466931   pi9_20240804_175250
# 2495702   pi9_20240804_175251
# 2426689   pi9_20240804_175259
#
#                                                       bbox     score  label
# 1095318  [1058.86865234375, 1173.1195068359375, 103.621...  0.258798      0
# 1000978  [1067.003662109375, 1171.5594482421875, 94.669...  0.279274      0
# 1025844  [1067.2371826171875, 1175.7403564453125, 90.08...  0.269532      0
# 1106638  [1058.7183837890625, 1173.383544921875, 120.09...  0.406223      0
# 1258626  [1068.4189453125, 1173.5277099609375, 87.54235...  0.331620      0
# ...                                                    ...       ...    ...
# ...
